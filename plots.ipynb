# %%
x= [(150, 1220.676025390625), (160, 965.8385620117188), (170, 784.223388671875), (180, 654.06103515625), (190, 565.8484497070312), (200, 493.07867431640625), (210, 446.6093444824219), (220, 408.2444763183594), (230, 371.9205322265625), (240, 340.7616271972656), (250, 317.0215759277344), (260, 295.8391418457031), (270, 275.7657775878906), (280, 260.5240783691406), (290, 252.25433349609375), (300, 246.69166564941406), (310, 240.84107971191406), (320, 236.57373046875), (330, 232.39707946777344), (340, 228.54931640625), (350, 224.50648498535156), (360, 221.59596252441406), (370, 219.2487335205078), (380, 219.9207763671875), (390, 215.72259521484375), (400, 214.29025268554688), (410, 212.8046112060547), (420, 211.49176025390625), (430, 210.14352416992188), (440, 208.77285766601562), (450, 207.7120361328125), (460, 207.2097625732422), (470, 206.23703002929688), (480, 205.4503936767578)]

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator

fig, ax = plt.subplots()
ax.plot([el[0] for el in x], [el[1] for el in x], linewidth=2.0)
x_locator = MultipleLocator(base=20)
plt.gca().xaxis.set_major_locator(x_locator)
y_locator = MultipleLocator(base=100)
plt.gca().yaxis.set_major_locator(y_locator)
ax.set_ylabel("average time per 1 batch, ms")
ax.set_xlabel("Power limit, watts")
# Out:
# Text(0.5, 0, 'Power limit, watts')

# %%
fastest = x[-1][1]
new_x= [(el[0],fastest/el[1]) for el in x]

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator
from matplotlib.pyplot import figure

plt.figure(figsize=(15, 5))
# new_x=new_x[10:]
plt.plot([el[0] for el in new_x], [el[1] for el in new_x], linewidth=2.0)
x_locator = MultipleLocator(base=10)
plt.gca().xaxis.set_major_locator(x_locator)
y_locator = MultipleLocator(base=0.05)
plt.gca().yaxis.set_major_locator(y_locator)
plt.ylabel("% of maximum performance")
plt.xlabel("Power limit, watts")
# plt.set_xlabel("Power limit, watts")
# Out:
# Text(0.5, 0, 'Power limit, watts')

# %%
new_x
# Out:
# [(150, 0.16830869895311676),
#  (160, 0.2127171162526694),
#  (170, 0.2619794265823916),
#  (180, 0.31411501776386563),
#  (190, 0.36308377938144043),
#  (200, 0.41666858531570006),
#  (210, 0.4600226041281233),
#  (220, 0.5032533337120828),
#  (230, 0.5524040107352928),
#  (240, 0.6029152852877515),
#  (250, 0.6480643882850124),
#  (260, 0.6944665685378165),
#  (270, 0.745017730168776),
#  (280, 0.7886042432732531),
#  (290, 0.8144573408485737),
#  (300, 0.8328225971311641),
#  (310, 0.8530537810348243),
#  (320, 0.8684412815813318),
#  (330, 0.8840489482366652),
#  (340, 0.8989324357092651),
#  (350, 0.9151200852401341),
#  (360, 0.9271396073117648),
#  (370, 0.9370653612352139),
#  (380, 0.9342018388191327),
#  (390, 0.9523823569438539),
#  (400, 0.9587481983057773),
#  (410, 0.9654414559552192),
#  (420, 0.9714345061486297),
#  (430, 0.9776670229943931),
#  (440, 0.9840857474175454),
#  (450, 0.9891116446684458),
#  (460, 0.9915092374286057),
#  (470, 0.9961857657064431),
# ...

# %%
def get_perc(arr):
    fastest = arr[-1][1] 
    return [(el[0],fastest/el[1]) for el in arr]

# %%
# # fp16_amp_2048 = get_perc(fp16_amp_2048,1220)


# fp16_torch_512 = [(150, 1294.404052734375), (160, 1001.3406982421875), (170, 820.8678588867188), (180, 682.02880859375), (190, 587.4188232421875), (200, 520.582275390625), (210, 473.0822448730469), (220, 431.44561767578125), (230, 411.7500915527344), (240, 394.61419677734375), (250, 379.3316650390625), (260, 364.99542236328125), (270, 355.36102294921875), (280, 348.5008544921875), (290, 343.0594787597656), (300, 337.4149475097656), (310, 332.4797668457031), (320, 328.1912536621094), (330, 323.7102966308594), (340, 320.6612243652344), (350, 317.421630859375), (360, 314.2767639160156), (370, 313.99822998046875), (380, 310.3531494140625), (390, 308.6546936035156), (400, 306.7710876464844), (410, 305.00616455078125), (420, 303.4029541015625), (430, 301.8724365234375), (440, 301.7656555175781), (450, 301.1462097167969), (460, 300.4386291503906), (470, 299.2185363769531), (480, 298.8428039550781)]
# fp16_torch_512 = get_perc(fp16_torch_512,205)

# fp16_trt_512 = [(150, 1220.676025390625), (160, 965.8385620117188), (170, 784.223388671875), (180, 654.06103515625), (190, 565.8484497070312), (200, 493.07867431640625), (210, 446.6093444824219), (220, 408.2444763183594), (230, 371.9205322265625), (240, 340.7616271972656), (250, 317.0215759277344), (260, 295.8391418457031), (270, 275.7657775878906), (280, 260.5240783691406), (290, 252.25433349609375), (300, 246.69166564941406), (310, 240.84107971191406), (320, 236.57373046875), (330, 232.39707946777344), (340, 228.54931640625), (350, 224.50648498535156), (360, 221.59596252441406), (370, 219.2487335205078), (380, 219.9207763671875), (390, 215.72259521484375), (400, 214.29025268554688), (410, 212.8046112060547), (420, 211.49176025390625), (430, 210.14352416992188), (440, 208.77285766601562), (450, 207.7120361328125), (460, 207.2097625732422), (470, 206.23703002929688), (480, 205.4503936767578)]
# fp16_trt_512 = get_perc(fp16_trt_512,205)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator
from matplotlib.pyplot import figure

# fp32_2048,tf32_2048,fp16_half_2048,fp16_amp_2048,fp16_torch_512,fp16_trt_512
# 'inference_fp32_2048','inference_tf32_2048','inference_fp16_half_2048','inference_fp16_amp_2048','inference_fp16_torch_512','inference_fp16_trt_512'

#fp32_train, tf32_train, fp16_amp_train, fp16_half_train

plt.figure(figsize=(15, 5))
for arr in [fp32_train, tf32_train, fp16_amp_train, fp16_half_train]:
    plt.plot([el[0] for el in arr], [el[1] for el in arr], linewidth=2.0)
x_locator = MultipleLocator(base=10)
plt.gca().xaxis.set_major_locator(x_locator)
y_locator = MultipleLocator(base=0.05)
plt.gca().yaxis.set_major_locator(y_locator)
plt.legend(['fp32_train', 'tf32_train', 'fp16_amp_train', 'fp16_half_train'], loc='upper left')
# plt.gca().set_ylabel("average time per 1 batch, ms")
# plt.gca().set_xlabel("Power limit, watts")

plt.ylabel("% of maximum performance")
plt.xlabel("Power limit, watts")
plt.show()


# import matplotlib.pyplot as plt
# import numpy as np
# from matplotlib.ticker import MultipleLocator

# fig, ax = plt.subplots()
# ax.plot([el[0] for el in x], [el[1] for el in x], linewidth=2.0)
# x_locator = MultipleLocator(base=20)
# plt.gca().xaxis.set_major_locator(x_locator)
# y_locator = MultipleLocator(base=100)
# plt.gca().yaxis.set_major_locator(y_locator)
# ax.set_ylabel("average time per 1 batch, ms")
# ax.set_xlabel("Power limit, watts")
